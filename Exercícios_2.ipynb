# %% [markdown]
# # Atividades Mínimas

# %%
#1 - Gaussianas com diferentes larguras e centros
'''
Realiza o plot do gráfico das funções Gaussiana com diferentes larguras e centros

Argumentos
------------------
  x_n : float
      Variavel que representa o valor de x.
  y_n : float
      Exponenciais.
'''

import matplotlib.pyplot as plt #importa a biblioteca com o código que constrói o gráfico
import numpy as np #importa a biblioteca com o código que organiza os dados e pontos do gráfico


x1 = np.arange (-5, 5, 0.1) # Aqui, a variável 'x' recebe valores entre -5 e 5 com 0.1 de espaço entre eles
y1 = np.exp(-x1**2) # Exponencial Gaussiana

plt.plot(x1, y1) # Realiza o plot de y por x
plt.tight_layout() # organiza o layout do gráfico
plt.xlabel('x')  # Define o rótulo do eixo x
plt.ylabel('y')  # Define o rótulo do eixo y
plt.title('Gráficos da função e^(-x^2)')  # Define o título do gráfico
plt.grid(True)  # Adiciona uma grade ao gráfico
plt.show() # Revela e mostra o gráfico

print("\n")


x2 = np.arange (3, 7, 0.1) # Aqui, a variável 'x' recebe valores entre -5 e 5 com 0.1 de espaço entre eles
y2 = 50*np.exp((-400*(x2 - 5)**2)) # Exponencial Gaussiana

plt.plot(x2, y2)
plt.tight_layout()
plt.xlabel('x')  # Define o rótulo do eixo x
plt.ylabel('y')  # Define o rótulo do eixo y
plt.title('Gráficos da função 50*e^(-400*(x - 5)^2)')  # Define o título do gráfico
plt.grid(True)  # Adiciona uma grade ao gráfico
plt.show()

print("\n")



x3 = np.arange (-15, 7, 0.1) # Aqui, a variável 'x' recebe valores entre -5 e 5 com 0.1 de espaço entre eles
y3 = 2*np.exp((-0.04*(x3 + 5)**2)) # Exponencial Gaussiana

plt.plot(x3, y3)
plt.tight_layout()
plt.xlabel('x')  # Define o rótulo do eixo x
plt.ylabel('y')  # Define o rótulo do eixo y
plt.title('Gráficos da função 2*e^(-0,04*(x + 5)^2)')  # Define o título do gráfico
plt.grid(True)  # Adiciona uma grade ao gráfico
plt.show()

# %%
#1 - sinc(x)
'''
Realiza o plot do gráfico da Função sinc(x)

Argumentos
------------------
  x : float
      Variavel que representa o valor de x.
  y : float
      Sinc(x).
'''
import matplotlib.pyplot as plt
import numpy as np

x = np.arange (-20, 20, 0.1) # Aqui, a variável 'x' recebe valores entre -5 e 5 com 0.1 de espaço entre eles
y = np.sin(x) / x # Função Sinc(x)

plt.plot(x, y)
plt.tight_layout()
plt.xlabel('x')  # Define o rótulo do eixo x
plt.ylabel('y')  # Define o rótulo do eixo y
plt.title('Gráficos da Função Sinc(x)')  # Define o título do gráfico
plt.grid(True)  # Adiciona uma grade ao gráfico
plt.show()

# %%
#1 - função exponencial
'''
Realiza o plot do gráfico da Função exponencial com diferentes valores de a
'''
import matplotlib.pyplot as plt
import numpy as np
a = [-10, -1, 2, 10]

n = 0

for n in range(len(a)):
    x = np.arange (0, 5, 0.1)
    y = np.exp(a[n]*x) # Função exponencial

    plt.plot(x, y)
    plt.tight_layout()
    plt.xlabel('x')  # Define o rótulo do eixo x
    plt.ylabel('y')  # Define o rótulo do eixo y
    plt.title(f'Gráficos da Função exp({a[n]}x)')  # Define o título do gráfico
    plt.grid(True)  # Adiciona uma grade ao gráfico
    plt.show()

# %%
#2 - Bhaskara
import matplotlib.pyplot as plt
import numpy as np

def bhaskara(a, b, c):
    '''
    Calcula e retorna as raízes de um polinômio de segundo grau utilizando a fórmula de Bhaskara

    Argumentos
    -----------
    delta: float
        Valor do discriminante.

    a, b, c: float
        Coeficientes do polinômio.

    Retorna
    -----------
    x1, x2: float
        As raízes do polinômio.

    '''

    if a == 0 :
      x1 = -c/b
      x2 = -c/b
      return x1, x2


    delta = b**2 - 4*a*c  # valor do discriminante

    x1 = (-b + delta**0.5) / (2*a) # primeira raiz
    x2 = (-b - delta**0.5) / (2*a) # segunda raiz

    return x1, x2 # tupla com as duas raízes

def f(x, a, b, c):
    '''
    Calcula e retorna o valor de uma função polinomial de segundo grau
     Argumentos
    -----------
    x: float
        Ponto em que a função é avaliada.
    a, b, c: float
        Coeficientes do polinômio.
    '''
    return a*x**2 + b*x + c

x1, x2 = bhaskara(1, 2, 3)
print(f'A primeira raiz é: {x1:.4f}')
print(f'A segunda raiz é: {x2: .4f}')
print("Caso 1: Discriminante negativo")
x = np.arange (-8, 6, 0.1)
y = x**2 + 2*x + 3

plt.plot(x, y, label ='Parte real')
plt.axhline(y=0, color='black', linewidth=1) #Evidencia o eixo y = 0
plt.axvline(x=0, color='black', linewidth=1) #Evidencia o eixo x = 0
plt.tight_layout()
plt.xlabel('x')  # Define o rótulo do eixo x
plt.ylabel('y')  # Define o rótulo do eixo y
plt.title(f'Gráfico da parte real da função x**2 + 2*x + 3')  # Define o título do gráfico
plt.grid(True)  # Adiciona uma grade ao gráfico
plt.show()

print("\n")

x1, x2 = bhaskara(1, 4, 4)
print('A primeira raiz é:', x1)
print('A segunda raiz é:', x2)
print("Caso 2: Discriminante igual à 0")
x = np.arange (-10, 6, 0.1)
y = x**2 + 4*x + 4

plt.plot(x, y)
plt.scatter([x1, x2], [f(x1, 1, 4, 4), f(x2, 1, 4, 4)], color='red', marker='o')
plt.axhline(y=0, color='black', linewidth=1)
plt.axvline(x=0, color='black', linewidth=1)
plt.tight_layout()
plt.xlabel('x')  # Define o rótulo do eixo x
plt.ylabel('y')  # Define o rótulo do eixo y
plt.title(f'Gráfico da parte real da função 2*x + 3')  # Define o título do gráfico
plt.grid(True)  # Adiciona uma grade ao gráfico
plt.show()

print("\n")

x1, x2 = bhaskara(2, 12, -14)
print('A primeira raiz é:', x1)
print('A segunda raiz é:', x2)
print("Caso 1: Discriminante positivo")
x = np.arange (-12, 6, 0.1)
y = 2*x**2 + 12*x + -14

plt.plot(x, y)
plt.scatter([x1, x2], [f(x1, 2, 12, -14), f(x2, 2, 12, -14)], color='red', marker='o')
plt.axhline(y=0, color='black', linewidth=1)
plt.axvline(x=0, color='black', linewidth=1)
plt.tight_layout()
plt.xlabel('x')  # Define o rótulo do eixo x
plt.ylabel('y')  # Define o rótulo do eixo y
plt.title(f'Gráfico da parte real da função 2*x + 3')  # Define o título do gráfico
plt.grid(True)  # Adiciona uma grade ao gráfico
plt.show()
# Out:
# A primeira raiz é: -1.0000+1.4142j
# A segunda raiz é: -1.0000-1.4142j
# Caso 1: Discriminante negativo
# A primeira raiz é: -2.0
# A segunda raiz é: -2.0
# Caso 2: Discriminante igual à 0
# A primeira raiz é: 1.0
# A segunda raiz é: -7.0
# Caso 1: Discriminante positivo
